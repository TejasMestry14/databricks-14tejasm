# %%
movies_df = spark.read.csv("/Volumes/workspace/default/14tejasm_vol/movies.csv", header=True, inferSchema=True)

# %%
moviemoviessmmovies_df.printSchema()

# %%
movies_df.createOrReplaceTempView("movies")

# %%
# %sql
SELECT primaryTitle, averageRating, numVotes
FROM movies
LIMIT 10

# %%
# %sql
SELECT genres, round(avg(averageRating), 2) AS avg_rating
FROM movies
GROUP BY genres
ORDER BY avg_rating DESC
LIMIT 10

# %%
from pyspark.sql.functions import avg, round
movies_df.groupBy("genres") \
    .agg(round(avg("averageRating"), 2).alias("avg_rating")) \
    .orderBy("avg_rating", ascending=False) \
    .show(10)

# %%
# %sql
SELECT primaryTitle, averageRating
FROM movies
WHERE averageRating >= 7

# %%
movies_df.filter("averageRating >= 7").display()
