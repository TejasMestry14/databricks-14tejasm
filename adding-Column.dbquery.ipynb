-- %%
-- ALTER TABLE workspace.default.walmart_dataset
-- ADD COLUMN temp_category STRING;

DESCRIBE workspace.default.walmart_dataset;
